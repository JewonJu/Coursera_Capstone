# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **Jewon Ju**
#
# Business Analyst

# %% [markdown]
# *I am interested in data science because I enjoy solving real-life problems using statistical techniques. In my professional career I want to use my background in economics and power of data science to generate new insights and solutions to modern businesses.*

# %% [markdown]
# ### Display the answer to $5 - 2$

# %%
ans = 5 -2 
print(ans)
# Out:
# 3

# %% [markdown]
# ---
#
# **NBA teams in Pacific Division**
#
# - LA Clippers
# - LA Lakers
# - Pheonix Suns
# - Sacramento Kings
# - Golden State Warriors
#
# ~~Steph Curry scored 62 points in a game!~~
#
# ![](https://i.kym-cdn.com/entries/icons/original/000/018/489/nick-young-confused-face-300x256-nqlyaa.jpg)
#
# [GOAT](https://en.wikipedia.org/wiki/Crying_Jordan#/media/File:Michael_Jordan_crying.jpg)
#
# ---
